# %%
yas = 150.0
kuru = 142.0
n = ( (yas - kuru) / yas ) * 100

print(f" Nem = % {n:,.2f}")
print()
yas_tonaj = 5000.0

kuru_tonaj = (1 - n / 100) * yas_tonaj

kayip_tonaj = yas_tonaj - kuru_tonaj

print(f"Yaş: {yas_tonaj}kg Kuru: {kuru_tonaj:.2f} ve Nem %{n:.2f}")
print()
print(f" Kayıp Tonaj =  {kayip_tonaj:.2f}")
print()
yas_baz = 27.5

kuru_baz = yas_baz / (1 - (n/100))

artis = kuru_baz - yas_baz

print(f"Yaş Baz : {yas_baz}kg Kuru Baz : {kuru_baz:.2f}kg")
print()
print(f"Artış : {artis: .2f}")
print()

print(f"""
            Tenor Raporu
----------------------------------------------
            Yaş Baz ->  {yas_baz}
            Artış Tenor -> {artıs}
-------------------------------------------------
""")
# Out:
#  Nem = % 5.33
#
# Yaş: 5000.0kg Kuru: 4733.33 ve Nem %5.33
#
#  Kayıp Tonaj =  266.67
#
# Yaş Baz : 27.5kg Kuru Baz : 29.05kg
#
# Artış :  1.55
#
#
#             Tenor Raporu
# ----------------------------------------------
#             Yaş Baz ->  27.5
#             Artış Tenor -> 1.549295774647888
# -------------------------------------------------

# %%
numune_b2o3_orani=29.5
alt_sinir = 28.0
ust_sinir = 48.0
fark = numune_b2o3_orani - alt_sinir

if alt_sinir <= numune_b2o3_orani <= ust_sinir :
  print(f"Uygundur.")
  print()
else :
 print(f"uygun Değildir")
 print()
print(f"Aradaki fark : {fark:.2f}")
print()
# Out:
# Uygundur.
#
# Aradaki fark : 1.50
